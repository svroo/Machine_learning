# %% [markdown]
# ### Especificaciones.
#
# Utilizando ambos datasets realiza lo siguiete:
# - Cargar el dataset
# - Crea un conjunto de entrenamiento del 70% de las intancias y el conjunto de pruebas con el 30% (set random_state = 0)
# - Utilizando el conjunto de entrenamiento crea un conjunto de validación con 3 pliegues
#
# Utilizando el conjunto de validación realiza lo siguiente con cada pliegue:
# - Utiliza Naive Bayes con distribución normal para entrenar y prueba el modelo en cada pliegue
#     - Determina la exactitud de cada pliegue
#     - Determina el promedio de exactitud

# %%
from Modulos import k_pliegues as kp
from Modulos import Naive_bayes as nv
from Modulos import Multinomial as mlt

# %%
k = 3
path = 'pliegues_email/'
y_test = kp.pliegues_validacion('./datasets/emails.csv', k, path, 0.3, True, 0)
# Out:
# Terminado los 3 pliegues

# %%
lista_precision = nv.inicializa_gaus(path, True, True)
# Out:
# 2363
#               precision    recall  f1-score   support
#
#          Yes       0.99      0.98      0.99      1732
#           No       0.94      0.99      0.96       681
#
#     accuracy                           0.98      2413
#    macro avg       0.97      0.98      0.97      2413
# weighted avg       0.98      0.98      0.98      2413
#
# [[ 672    9]
#  [  41 1691]]
# Pliegue 1, terminado
# 2371
#               precision    recall  f1-score   support
#
#          Yes       0.99      0.99      0.99      1681
#           No       0.97      0.98      0.97       732
#
#     accuracy                           0.98      2413
#    macro avg       0.98      0.98      0.98      2413
# weighted avg       0.98      0.98      0.98      2413
#
# [[ 715   17]
#  [  25 1656]]
# Pliegue 2, terminado
# 2346
#               precision    recall  f1-score   support
#
#          Yes       1.00      0.96      0.98      1709
#           No       0.92      1.00      0.95       705
#
#     accuracy                           0.97      2414
#    macro avg       0.96      0.98      0.97      2414
# weighted avg       0.97      0.97      0.97      2414
#
# [[ 702    3]
#  [  65 1644]]
# Pliegue 3, terminado

# %%
print(lista_precision)
# Out:
# [0.9792789059262329, 0.9825942809780357, 0.971830985915493]

# %%
exactitud = nv.kpliegues_vs_test(path, True, True)
# Out:
# 1524
#               precision    recall  f1-score   support
#
#          Yes       1.00      0.98      0.99      1111
#           No       0.94      1.00      0.97       441
#
#     accuracy                           0.98      1552
#    macro avg       0.97      0.99      0.98      1552
# weighted avg       0.98      0.98      0.98      1552
#
# [[ 439    2]
#  [  26 1085]]
# Pliegue 1, terminado

# %%
nv.get_tableau('email', 0, 3)
# Out:
# Promedio: 0.9779013909399206
# pliegues vs test 0.9819587628865979
# +-----------+----------------+--------------------------------------------+---------------------------------------+
# | Dataset   | Clasificador   |  Exactitud, promedio de los tres pliegues  |  Exactitud obtenida pliegues vs test  |
# +===========+================+============================================+=======================================+
# | email     | Naive Bayes    |                  0.977901                  |               0.981959                |
# +-----------+----------------+--------------------------------------------+---------------------------------------+

# %% [markdown]
# - Utiliza Multinomial con distribución normal para entrenar y prueba el modelo en cada pliegue
#     - Determina la exactitud de cada pliegue
#     - Determina el promedio de exactitud de los 3 pliegues

# %%
lista_multi = mlt.inicia_multi(path, True, True)
# Out:
# 1766
#               precision    recall  f1-score   support
#
#          Yes       0.79      0.85      0.82      1732
#           No       0.53      0.43      0.48       681
#
#     accuracy                           0.73      2413
#    macro avg       0.66      0.64      0.65      2413
# weighted avg       0.72      0.73      0.72      2413
#
# [[ 294  387]
#  [ 260 1472]]
# Pliegue 1, terminado
# 1769
#               precision    recall  f1-score   support
#
#          Yes       0.78      0.86      0.82      1681
#           No       0.58      0.45      0.51       732
#
#     accuracy                           0.73      2413
#    macro avg       0.68      0.65      0.66      2413
# weighted avg       0.72      0.73      0.72      2413
#
# [[ 330  402]
#  [ 242 1439]]
# Pliegue 2, terminado
# 1806
#               precision    recall  f1-score   support
#
#          Yes       0.79      0.87      0.83      1709
#           No       0.59      0.45      0.51       705
#
#     accuracy                           0.75      2414
#    macro avg       0.69      0.66      0.67      2414
# weighted avg       0.73      0.75      0.74      2414
#
# [[ 320  385]
#  [ 223 1486]]
# Pliegue 3, terminado

# %%
print(lista_multi)
# Out:
# [0.7318690426854538, 0.7331123083298798, 0.748135874067937]

# %%
lista_test_vs_pliegue = mlt.multinomial_vs_test(path, True, True)
# Out:
# 1152
#               precision    recall  f1-score   support
#
#          Yes       0.80      0.85      0.83      1111
#           No       0.55      0.47      0.51       441
#
#     accuracy                           0.74      1552
#    macro avg       0.68      0.66      0.67      1552
# weighted avg       0.73      0.74      0.74      1552
#
# [[207 234]
#  [166 945]]
# Pliegue 1, terminado

# %%
lista_test_vs_pliegue
# Out:
# [0.7318690426854538, 0.7331123083298798, 0.748135874067937, 0.7422680412371134]

# %%
mlt.get_tableau('email', 4, 7)
# Out:
# promedio: 0.738846316580096
# pliegues vs test: nan
# +-----------+----------------+--------------------------------------------+---------------------------------------+
# | Dataset   | Clasificador   |  Exactitud, promedio de los tres pliegues  |  Exactitud obtenida pliegues vs test  |
# +===========+================+============================================+=======================================+
# | email     | multinomial    |                  0.738846                  |                  nan                  |
# +-----------+----------------+--------------------------------------------+---------------------------------------+
# C:\Users\hp\Documents\VSCode\Machine_learning\Practica 6\Modulos\Multinomial.py:86: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sum(lista) / n

# %% [markdown]
# Ahora con el dataset de **iris**

# %%
k = 3
path = 'pliegues_iris/'
y_test = kp.pliegues_validacion('./datasets/iris.csv', k, path, 0.3, True, 0)
# Out:
# Terminado los 3 pliegues

# %%
lista_precision = nv.inicializa_gaus(path)
# Out:
# 68
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        27
# Iris-versicolor       1.00      0.89      0.94        18
#  Iris-virginica       0.93      1.00      0.96        25
#
#        accuracy                           0.97        70
#       macro avg       0.98      0.96      0.97        70
#    weighted avg       0.97      0.97      0.97        70
#
# [[27  0  0]
#  [ 0 16  2]
#  [ 0  0 25]]
# Pliegue 1, terminado
# 64
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.89      0.89      0.89        27
#  Iris-virginica       0.88      0.88      0.88        25
#
#        accuracy                           0.91        70
#       macro avg       0.92      0.92      0.92        70
#    weighted avg       0.91      0.91      0.91        70
#
# [[18  0  0]
#  [ 0 24  3]
#  [ 0  3 22]]
# Pliegue 2, terminado
# 67
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        23
# Iris-versicolor       0.90      0.95      0.92        19
#  Iris-virginica       0.96      0.93      0.95        28
#
#        accuracy                           0.96        70
#       macro avg       0.95      0.96      0.96        70
#    weighted avg       0.96      0.96      0.96        70
#
# [[23  0  0]
#  [ 0 18  1]
#  [ 0  2 26]]
# Pliegue 3, terminado

# %%
print(lista_precision)
# Out:
# [0.9792789059262329, 0.9825942809780357, 0.971830985915493, 0.9819587628865979, 0.9714285714285714, 0.9142857142857143, 0.9571428571428572]

# %%
exactitud = nv.kpliegues_vs_test(path)
# Out:
# 45
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       1.00      1.00      1.00        18
#  Iris-virginica       1.00      1.00      1.00        11
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
#
# [[16  0  0]
#  [ 0 18  0]
#  [ 0  0 11]]
# Pliegue 1, terminado

# %%
nv.get_tableau('iris',4, 7)
# Out:
# Promedio: 0.9476190476190477
# pliegues vs test 1.0
# +-----------+----------------+--------------------------------------------+---------------------------------------+
# | Dataset   | Clasificador   |  Exactitud, promedio de los tres pliegues  |  Exactitud obtenida pliegues vs test  |
# +===========+================+============================================+=======================================+
# | iris      | Naive Bayes    |                  0.947619                  |                   1                   |
# +-----------+----------------+--------------------------------------------+---------------------------------------+

# %%
lista_multi = mlt.inicia_multi(path)
# Out:
# 52
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        27
# Iris-versicolor       0.00      0.00      0.00        18
#  Iris-virginica       0.58      1.00      0.74        25
#
#        accuracy                           0.74        70
#       macro avg       0.53      0.67      0.58        70
#    weighted avg       0.59      0.74      0.65        70
#
# [[27  0  0]
#  [ 0  0 18]
#  [ 0  0 25]]
# C:\Users\hp\anaconda3\envs\sklearn\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\hp\anaconda3\envs\sklearn\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\hp\anaconda3\envs\sklearn\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Pliegue 1, terminado
# 63
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.79      1.00      0.89        27
#  Iris-virginica       1.00      0.72      0.84        25
#
#        accuracy                           0.90        70
#       macro avg       0.93      0.91      0.91        70
#    weighted avg       0.92      0.90      0.90        70
#
# [[18  0  0]
#  [ 0 27  0]
#  [ 0  7 18]]
# Pliegue 2, terminado
# 51
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        23
# Iris-versicolor       0.00      0.00      0.00        19
#  Iris-virginica       0.60      1.00      0.75        28
#
#        accuracy                           0.73        70
#       macro avg       0.53      0.67      0.58        70
#    weighted avg       0.57      0.73      0.63        70
#
# [[23  0  0]
#  [ 0  0 19]
#  [ 0  0 28]]
# C:\Users\hp\anaconda3\envs\sklearn\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\hp\anaconda3\envs\sklearn\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\hp\anaconda3\envs\sklearn\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Pliegue 3, terminado

# %%
lista_test_vs_pliegue = mlt.multinomial_vs_test(path)
# Out:
# 34
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       0.62      1.00      0.77        18
#  Iris-virginica       0.00      0.00      0.00        11
#
#        accuracy                           0.76        45
#       macro avg       0.54      0.67      0.59        45
#    weighted avg       0.60      0.76      0.66        45
#
# [[16  0  0]
#  [ 0 18  0]
#  [ 0 11  0]]
# C:\Users\hp\anaconda3\envs\sklearn\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\hp\anaconda3\envs\sklearn\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\hp\anaconda3\envs\sklearn\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Pliegue 1, terminado

# %%
lista_test_vs_pliegue
# Out:
# [0.7318690426854538,
#  0.7331123083298798,
#  0.748135874067937,
#  0.7422680412371134,
#  0.7428571428571429,
#  0.9,
#  0.7285714285714285,
#  0.7555555555555555]

# %%
mlt.get_tableau('iris',4, 7)
# Out:
# promedio: 0.760973405392708
# pliegues vs test: 0.7555555555555555
# +-----------+----------------+--------------------------------------------+---------------------------------------+
# | Dataset   | Clasificador   |  Exactitud, promedio de los tres pliegues  |  Exactitud obtenida pliegues vs test  |
# +===========+================+============================================+=======================================+
# | iris      | multinomial    |                  0.760973                  |               0.755556                |
# +-----------+----------------+--------------------------------------------+---------------------------------------+
